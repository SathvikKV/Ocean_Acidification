# %% [markdown]
# # Ocean Acidification and pH Level Trend Analysis
#
# ## INFO 6105 Final Project
#
# ### Team Members - Sathvik Vadavatha, Revanth Padala and Kaushik Venkat Sai Karanam

# %% [markdown]
# ## Background
#
# The ocean is a fundamental component of our planet, providing us with the air we breathe and the water we drink. The health of our planet is intimately tied to the state of its oceans, which are responsible for producing about 70% of the oxygen we breathe and are a crucial source of hydration and nutrition. As the origin of an incredible variety of biodiversity and a critical element of worldwide weather patterns, the ocean is undoubtedly essential to our survival and the well-being of Earth's extensive ecological networks.
#
# Regrettably, these vital oceans are under threat from a range of severe dangers that put their ability to sustain life and maintain environmental equilibrium in danger. The relentless surge in greenhouse gas emissions that drives global climate change has resulted in widespread disruption of marine habitats. The ocean's function as a carbon sink has resulted in a phenomenon known as ocean acidification, which reduces pH levels and undermines the foundation of marine ecosystems.
#
# Unfortunately, the ocean is facing numerous threats such as global climate change, ocean acidification, reductionce in pH levels, pollution, habitat destruction, invasive species, and a significant decrease in ocean fish stocks. These threats have severely impacted more than 40 percent of the ocean, and no area has been left untouched.
#
# <img src="images/our-ocean.jpg" alt="Ocean Importance" width="700" height="500"/>

# %% [markdown]
# # Ocean Acidification
#
# Ocean acidification, often called the 'evil twin' of global warming, seriously threatens our planet's oceans. It occurs when the ocean absorbs excess carbon dioxide from the atmosphere, which leads to chemical reactions that reduce pH, carbonate ion concentration, and saturation states of biologically important calcium carbonate minerals. These minerals are essential for the shells and skeletons of many marine organisms, and their depletion can have harmful effects, especially on coral reefs, shellfish, and plankton, which are the foundational components of the marine food web.
#
# Pollution also significantly impacts the health of the oceans. Plastics, toxic runoff, and other contaminants harm marine life. Habitat destruction, from coastal erosion to the destruction of mangroves and seagrass beds, further weakens the ocean's ability to support the numerous species it houses. Invasive species introduced through shipping and other human activities are outcompeting native marine life, disrupting the delicate balance that has evolved over millennia.
#
# The culmination of these pressures is a significant reduction in ocean fish stocks. This worrying trend threatens the marine food chain and endangers billions of people's livelihoods and food security worldwide. With over 40 percent of the ocean heavily impacted by human activities, no area remains unaffected by our influence.
#
#
# <img src="images/Acidification_1.png" alt="Ocean Importance" width="900" height="900"/>

# %% [markdown]
# # Dataset Sources
#
# 1. **Global CO2 Emissions by Region**
#    - Data Source: [Our World in Data - Annual CO₂ emissions](https://ourworldindata.org/grapher/annual-co2-emissions-per-country)
#    - Citation: Hannah Ritchie, Pablo Rosado and Max Roser (2023) - “CO₂ and Greenhouse Gas Emissions”. Data adapted from Global Carbon Project.
#
#
# 2. **Ocean Acidification: Mean Seawater pH**
#    - Data Source: [Our World in Data - Seawater pH](https://ourworldindata.org/grapher/seawater-ph)
#    - Citation: School of Ocean & Earth Science & Technology - Hawaii Ocean Time-series (2023), with minor processing by Our World in Data.
#
#
# 3. **Ocean Carbon Dioxide Levels and Acidity, 1983-2018**
#    - Data Source: [EPA - Climate Indicators](https://www.epa.gov/climate-indicators)
#    - Citations: Bates, 2016; González-Dávila, 2012; University of South Florida, 2021; University of Hawaii, 2021.
#
#
# 4. **Sampling events from the Tara Pacific Expedition**
#    - Data Source: [PANGAEA - Tara Pacific Expedition](https://doi.org/10.1594/PANGAEA.944548)
#    - Citation: Bourdin, Guillaume et al. (2022): Sampling events from the Tara Pacific Expedition 2016-2018.

# %% [markdown]
# # Plotting Annual CO2 Emissions for Selected Regions
#
# ## Introduction
# In this Python code, we analyze and visualize annual CO2 emissions data for several regions of interest using the Pandas
#
# ## Data Preparation
# - We start by importing the necessary libraries: `pandas` for data handling and `matplotlib.pyplot` for plotting.
# - Next, we read a CSV file containing CO2 emissions data into a Pandas DataFrame.
#
# ## Filtering Data
# - We filter the DataFrame to include only the regions of interest, such as 'World', 'China', 'United States', 'India', 'Germany', 'Brazil', 'United Kingdom', and 'France'.
#
# ## Plotting
# - We define a color palette to assign a unique color to each region.
# - A single plot is created.
# - Iterating over each region, we plot its annual CO2 emissions data over the years.
#
# ## Conclusion
# This visualization illustrates the global increase in CO2 emissions, providing essential context for understanding the importance of studying ocean acidification.

# %% [markdown]
# ### Importing the necessary libraries for data manipulation and visualizations.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Reading a CSV file containing annual CO2 levels of each country in different years.

# %%
df = pd.read_csv("data/co2emissons.csv")
df.head()
# Out:
#         Entity Code  Year  Annual CO2 E
# 0  Afghanistan  AFG  1949       14656.0
# 1  Afghanistan  AFG  1950       84272.0
# 2  Afghanistan  AFG  1951       91600.0
# 3  Afghanistan  AFG  1952       91600.0
# 4  Afghanistan  AFG  1953      106256.0

# %% [markdown]
# ### Quick overview of the DataFrame's structure and content

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30308 entries, 0 to 30307
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Entity        30308 non-null  object
#  1   Code          24157 non-null  object
#  2   Year          30308 non-null  int64
#  3   Annual CO2 E  30308 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 947.3+ KB

# %%
df.isnull().sum(axis=0)
# Out:
# Entity             0
# Code            6151
# Year               0
# Annual CO2 E       0
# dtype: int64

# %%
df.describe()
# Out:
#                Year  Annual CO2 E
# count  30308.000000  3.030800e+04
# mean    1940.191336  3.912722e+08
# std       65.510232  1.855825e+09
# min     1750.000000  0.000000e+00
# 25%     1902.000000  1.832000e+05
# 50%     1959.000000  3.856092e+06
# 75%     1991.000000  4.727752e+07
# max     2022.000000  3.714979e+10

# %% [markdown]
# ### Importing the necessary libraries

# %%
# !pip install statsmodels

# %% [markdown]
# ### Generating the visualization for CO2 emmissions for each country over the years

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file into a pandas DataFrame
df = pd.read_csv("data/co2emissons.csv")

# Filter the DataFrame to include only the regions of interest
regions_of_interest = ['World','China', 'United States', 'India', 'Germany', 'Brazil', 'United Kingdom', 'France']
df_filtered = df[df['Entity'].isin(regions_of_interest)]

# Set up a color palette for each region
colors = ['blue', 'green', 'red', 'purple', 'orange', 'cyan', 'magenta','teal']

# Create a single plot for all regions
plt.figure(figsize=(10, 6))

# Iterate over each region and plot its data with a unique color and label
for i, region in enumerate(regions_of_interest):
    # Filter data for the current region
    region_data = df_filtered[df_filtered['Entity'] == region]
    
    # Plot the data
    plt.plot(region_data['Year'], region_data['Annual CO2 E'], marker='o', linestyle='-', color=colors[i], label=region)

# Add labels, title, grid, and legend
plt.title('Annual CO2 Emissions')
plt.xlabel('Year')
plt.ylabel('Annual CO2 Emissions')
plt.grid(True)
plt.legend()

# Set x-axis limits
plt.xlim(1920, df['Year'].max())

plt.show()

# %% [markdown]
# # Forecasting Annual CO2 Emissions for the World
#
# ## Introduction
# The following code aims to forecast future annual CO2 emissions for the world using the ARIMA (AutoRegressive Integrated Moving Average) model. ARIMA is a time series forecasting method that captures temporal patterns and seasonality in data, making it suitable for predicting CO2 emissions trends.
#
# ## Forecasting
# - Define the ARIMA model with order (1, 1, 1) to model CO2 emissions data.
# - Fit the ARIMA model to historical data to learn patterns.
# - Generate predictions for the next 20 years using the fitted model.

# %% [markdown]
# ### Importing the necessary libraries for data manipulation and visualizations.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
import numpy as np

# %% [markdown]
# ### Reading a CSV file containing annual CO2 levels of each country in different years.

# %%
# Read the CSV file into a pandas DataFrame
df = pd.read_csv("data/co2emissons.csv")
df.head()
# Out:
#         Entity Code  Year  Annual CO2 E
# 0  Afghanistan  AFG  1949       14656.0
# 1  Afghanistan  AFG  1950       84272.0
# 2  Afghanistan  AFG  1951       91600.0
# 3  Afghanistan  AFG  1952       91600.0
# 4  Afghanistan  AFG  1953      106256.0

# %%
# Filter the DataFrame to include only the "World" entity
df_world = df[df['Entity'] == 'World']

# Aggregate data across all regions for simplicity
df_aggregated = df_world.groupby('Year')['Annual CO2 E'].sum().reset_index()

# Define the ARIMA model
model = ARIMA(df_aggregated['Annual CO2 E'], order=(1, 1, 1))  # You might need to adjust the order based on model performance

# Fit the model
model_fit = model.fit()

# Make predictions for the next 20 years
forecast = model_fit.forecast(steps=20)

# Get the next 20 years
next_20_years = np.arange(df_aggregated['Year'].max() + 1, df_aggregated['Year'].max() + 21)

# Plot the historical data
plt.figure(figsize=(10, 6))
plt.plot(df_aggregated['Year'], df_aggregated['Annual CO2 E'], marker='o', linestyle='-', color='blue', label='Historical Data')

# Plot the predicted values for the next 20 years
plt.plot(next_20_years, forecast, marker='o', linestyle='-', color='red', label='Predicted Values')

plt.title('Annual CO2 Emissions Forecast for World')
plt.xlabel('Year')
plt.ylabel('Annual CO2 Emissions (ten billion tonnes)')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# C:\Users\sathu\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'

# %% [markdown]
# # Data Analysis and Forecasting of Ocean pH Levels
#
# ## Introduction
# Next, we analyze data on ocean pH levels and use the ARIMA (AutoRegressive Integrated Moving Average) model to forecast future pH levels. The analysis includes data preprocessing, visualization, and forecasting.
#
# ## Data Preprocessing
# - The script reads a CSV file containing seawater pH data into a Pandas DataFrame.
# - Missing values in the 'Rolling yearly average of ocean pH levels' column are filled with the mean value calculated from the available data.
#
# ## Exploratory Data Analysis (EDA)
# - Histograms are plotted for each column in the DataFrame, showing the distribution of ocean pH levels.
# - The 'Day' column is converted to datetime format and set as the index for time series analysis.
#
# ## Time Series Visualization
# - A time series plot is generated to visualize the monthly measurements of ocean pH levels over time.
#
# ## Forecasting with ARIMA
# - An ARIMA model is fitted to the time series data using an order of (5,1,0), indicating auto-regressive terms, differencing, and moving average terms.
# - The model is used to forecast ocean pH levels for the next 12 months.
# - Original data and forecasted values are plotted together to visualize the predicted trend in ocean pH levels.
#
# ## Conclusion
# This analysis provides insights into the historical trends and future projections of ocean pH levels, aiding in understanding and monitoring the dynamics of ocean acidification.

# %%
df = pd.read_csv("data/seawater-ph.csv")
df.head()
# Out:
#    Entity  Code         Day  Monthly measurement of ocean pH levels  \
# 0  Hawaii   NaN  1988-10-31                                  8.1097
# 1  Hawaii   NaN  1988-12-02                                  8.1092
# 2  Hawaii   NaN  1989-01-08                                  8.1168
# 3  Hawaii   NaN  1989-02-26                                  8.1316
# 4  Hawaii   NaN  1989-03-27                                  8.1218
#
#    Rolling yearly average of ocean pH levels
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330 entries, 0 to 329
# Data columns (total 5 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Entity                                     330 non-null    object
#  1   Code                                       0 non-null      float64
#  2   Day                                        330 non-null    object
#  3   Monthly measurement of ocean pH levels     330 non-null    float64
#  4   Rolling yearly average of ocean pH levels  319 non-null    float64
# dtypes: float64(3), object(2)
# memory usage: 13.0+ KB

# %%
df.isnull().sum(axis=0)
# Out:
# Entity                                         0
# Code                                         330
# Day                                            0
# Monthly measurement of ocean pH levels         0
# Rolling yearly average of ocean pH levels     11
# dtype: int64

# %%
# Calculate the mean of the column
mean_rolling_avg = df['Rolling yearly average of ocean pH levels'].mean()
# mean_co2_avg = df['Hawaii pCO2'].mean()

# Replace NaN values with the calculated mean
df['Rolling yearly average of ocean pH levels'].fillna(value=mean_rolling_avg, inplace=True)
# df['Hawaii pCO2'].fillna(value=mean_co2_avg, inplace=True)

# Verify the changes
print(df.isna().sum())

# # Optionally, save the modified DataFrame to a new file
df.to_csv('modified_seawater_ph.csv', index=False)
# Out:
# Entity                                         0
# Code                                         330
# Day                                            0
# Monthly measurement of ocean pH levels         0
# Rolling yearly average of ocean pH levels      0
# dtype: int64

# %%
df.describe()
# Out:
#        Code  Monthly measurement of ocean pH levels  \
# count   0.0                              330.000000
# mean    NaN                                8.084312
# std     NaN                                0.022277
# min     NaN                                8.027200
# 25%     NaN                                8.069150
# 50%     NaN                                8.083600
# 75%     NaN                                8.098950
# max     NaN                                8.150800
#
#        Rolling yearly average of ocean pH levels
# count                                 330.000000
# mean                                    8.084228
# std                                     0.016850
# min                                     8.045435
# 25%                                     8.069319
# 50%                                     8.085845
# 75%                                     8.096217
# max                                     8.114453

# %% [markdown]
# ### Generating histograms in the DataFrame using Matplotlib and Seaborn libraries to visualize the distributions and frequency of measurement of ocean pH levels.

# %%
plt.figure(figsize=(12, 8))
for column in df.columns[2:]:
    plt.figure(figsize=(10,6))
    sns.histplot(df[column], kde=True, bins=30, color='darkblue')
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Count')
    plt.show()

# %% [markdown]
# # Visualizations over time & Analysis
#
# ### For Monthly measurement of ocean pH levels

# %%
# Convert 'Day' column to datetime
df['Day'] = pd.to_datetime(df['Day'])

# Set 'Day' column as the index
df.set_index('Day', inplace=True)

# Plot time series of 'Monthly measurement of ocean pH levels'
plt.figure(figsize=(10, 6))
sns.lineplot(data=df['Monthly measurement of ocean pH levels'], marker='o', color='blue')
plt.title('Monthly Measurement of Ocean pH Levels Over Time')
plt.xlabel('Date')
plt.ylabel('Ocean pH Levels')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Statistical analysis

# %%
mean_ph = df['Monthly measurement of ocean pH levels'].mean()
std_ph = df['Monthly measurement of ocean pH levels'].std()
max_ph = df['Monthly measurement of ocean pH levels'].max()
min_ph = df['Monthly measurement of ocean pH levels'].min()

print(f"Mean pH: {mean_ph:.2f}")
print(f"Standard Deviation of pH: {std_ph:.2f}")
print(f"Maximum pH: {max_ph:.2f}")
print(f"Minimum pH: {min_ph:.2f}")
# Out:
# Mean pH: 8.08
# Standard Deviation of pH: 0.02
# Maximum pH: 8.15
# Minimum pH: 8.03

# %% [markdown]
# # Visualizations over time & Analysis
#
# ### Rolling yearly average of ocean pH levels

# %%
# Plot time series of 'Rolling yearly average of ocean pH levels'
plt.figure(figsize=(10, 6))
sns.lineplot(data=df['Rolling yearly average of ocean pH levels'], marker='o', color='red')
plt.title('Rolling Yearly Average of Ocean pH Levels Over Time')
plt.xlabel('Date')
plt.ylabel('Ocean pH Levels')
plt.grid(True)
plt.show()

# %% [markdown]
# # Time Series Forecasting of Ocean pH Levels using ARIMA Model

# %% [markdown]
# ### Importing the necessary libraries for data manipulation and visualizations.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# %% [markdown]
# ### Plotting the time series of the pH levels over time

# %%
# Plot time series of 'Monthly measurement of ocean pH levels'
plt.figure(figsize=(10, 6))
plt.plot(df['Monthly measurement of ocean pH levels'], marker='o', color='blue')
plt.title('Monthly Measurement of Ocean pH Levels Over Time')
plt.xlabel('Date')
plt.ylabel('Ocean pH Levels')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Fitting the ARIMA model to the dataset

# %%
# Fit ARIMA model
model = ARIMA(df['Monthly measurement of ocean pH levels'], order=(5,1,0))  # ARIMA(p,d,q)
model_fit = model.fit()
# Out:
# C:\Users\sathu\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\sathu\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\sathu\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
# Make predictions for the next 12 months (adjust as needed)
future_periods = 12
forecast = model_fit.forecast(steps=future_periods)
# Out:
# C:\Users\sathu\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\sathu\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %% [markdown]
# ### Plotting the forecasted values using ARIMA model

# %%
# Plot original data and forecasted values
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Monthly measurement of ocean pH levels'], label='Original Data', marker='o', color='blue')
plt.plot(pd.date_range(start=df.index[-1], periods=future_periods+1, freq='M')[1:], forecast, label='Forecast', marker='o', color='red')
plt.title('Forecast of Ocean pH Levels')
plt.xlabel('Date')
plt.ylabel('Ocean pH Levels')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Continuation: Analysis of pCO2 Levels in the Pacific Ocean
#
# ### Time Series Visualization
# - A time series plot is generated to visualize the trend of pCO2 levels in the Pacific Ocean over time.
#
# ### Statistical Summary
# - The statistical summary of pCO2 levels in the Pacific Ocean is presented.
# - A bar chart displays the mean pCO2 value with error bars representing the standard deviation.
# - Maximum and minimum pCO2 values are indicated as points on the plot.
#
# ### Time Series Forecasting with ARIMA
# - An ARIMA model is fitted to the time series data of Hawaii pCO2 levels.
# - The ARIMA model forecasts Hawaii pCO2 levels for the next 12 months.
#
# ### Conclusion
# This analysis provides insights into the historical trends and future projections of pCO2 levels in the Pacific Ocean, contributing to our understanding of oceanic carbon dynamics and its implications for climate change.

# %% [markdown]
# ### Reading a CSV file to get the relation between CO2 and pH values.

# %%
df = pd.read_csv("data/ph_co2.csv")
df.head()
# Out:
#           Day  Hawaii pH  Hawaii pCO2  Canary Islands Year  Canary Islands pH  \
# 0  1988-10-31     8.1097        330.9            1995.7507             8.0765
# 1  1988-12-02     8.1092        330.6            1995.7562             8.0743
# 2  1989-01-08     8.1168        324.3            1995.7644             8.0713
# 3  1989-02-26     8.1316        310.9            1995.9014             8.0837
# 4  1989-03-27     8.1218        317.7            1996.0656             8.1117
#
#    Canary Islands pCO2  Unnamed: 6  Bermuda Year  Bermuda pH  Bermuda pCO2  \
# 0             377.6526         NaN     1983.6959       8.070       363.187
# 1             380.0385         NaN     1983.7726       8.088       343.941
# 2             383.1138         NaN     1984.0712       8.146       299.199
# 3             370.4347         NaN     1984.1836       8.145       301.419
# 4             343.0605         NaN     1984.3260       8.144       302.309
#
# ...

# %% [markdown]
# ### Plotting the pCO2 values over time.

# %%
# Convert 'Day' column to datetime
df['Day'] = pd.to_datetime(df['Day'])

# Set 'Day' column as the index
df.set_index('Day', inplace=True)

# Plot time series of 'Hawaii pCO2'
plt.figure(figsize=(10, 6))
sns.lineplot(data=df['Hawaii pCO2'], marker='o', color='blue')
plt.title('Pacific Ocean pCO2 Over Time')
plt.xlabel('Date')
plt.ylabel('pCO2')
plt.grid(True)
plt.show()

# %%
# Statistical analysis
mean_pCO2 = df['Hawaii pCO2'].mean()
std_pCO2 = df['Hawaii pCO2'].std()
max_pCO2 = df['Hawaii pCO2'].max()
min_pCO2 = df['Hawaii pCO2'].min()

print(f"Mean Hawaii pCO2: {mean_pCO2:.2f}")
print(f"Standard Deviation of Hawaii pCO2: {std_pCO2:.2f}")
print(f"Maximum Hawaii pCO2: {max_pCO2:.2f}")
print(f"Minimum Hawaii pCO2: {min_pCO2:.2f}")
# Out:
# Mean Hawaii pCO2: 353.51
# Standard Deviation of Hawaii pCO2: 20.01
# Maximum Hawaii pCO2: 400.20
# Minimum Hawaii pCO2: 298.30

# %%
mean_pCO2 = 353.51
std_pCO2 = 20.01
max_pCO2 = 400.20
min_pCO2 = 298.30

# Setting the positions for the bars and the width
positions = [0]
width = 0.5

# Creating the bar for the mean value
plt.bar(positions, [mean_pCO2], width=width, color='skyblue', yerr=std_pCO2, capsize=7, label='Mean Hawaii pCO2')

# Adding the max and min values as points on the plot
plt.plot(positions, [max_pCO2], 'k^', label='Max Hawaii pCO2')
plt.plot(positions, [min_pCO2], 'kv', label='Min Hawaii pCO2')

# Adding some aesthetics
plt.ylabel('pCO2 in ppm')
plt.title('Statistical Summary of pCO2 in Pacific Ocean')
plt.xticks([]) # No x-ticks are needed since we only have one bar
plt.legend()

# Optionally adding the numerical values as text on the plot
plt.text(positions[0], mean_pCO2, f'{mean_pCO2:.2f}', ha='center', va='bottom')
plt.text(positions[0], max_pCO2, f'{max_pCO2:.2f}', ha='center', va='bottom')
plt.text(positions[0], min_pCO2, f'{min_pCO2:.2f}', ha='center', va='bottom')

# Display the plot
plt.show()

# %% [markdown]
# # Upword Trend Prediction

# %% [markdown]
# ### Importing the necessary libraries for data manipulation and visualizations.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.arima.model import ARIMA

# %% [markdown]
# ### Plotting the pCO2 values over time.

# %%
# Plot time series of 'Hawaii pCO2'
plt.figure(figsize=(10, 6))
sns.lineplot(data=df['Hawaii pCO2'], marker='o', color='blue')
plt.title('Hawaii pCO2 Over Time')
plt.xlabel('Year')
plt.ylabel('Hawaii pCO2')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Fitting the ARIMA model to the Dataset

# %%
# Fit ARIMA model
model = ARIMA(df['Hawaii pCO2'], order=(5,1,0))  # ARIMA(p,d,q)
model_fit = model.fit()
# Out:
# C:\Users\sathu\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\sathu\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\sathu\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
# Make predictions for the next 12 months
future_periods = 12
forecast = model_fit.forecast(steps=future_periods)
# Out:
# C:\Users\sathu\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\sathu\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %% [markdown]
# ### Plotting the forecasted values using ARIMA model

# %%
# Plot original data and forecasted values for the next 12 months
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Hawaii pCO2'], label='Original Data', marker='o', color='blue')
plt.plot(pd.date_range(start=df.index[-1], periods=future_periods+1, freq='M')[1:], forecast, label='Forecast', marker='o', color='red')
plt.title('Forecast of Hawaii pCO2 for Next 12 Months')
plt.xlabel('Month')
plt.ylabel('Hawaii pCO2')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Data Analysis of Carbonate Chemistry
#
#
# ### H+ and HCO3- background
#
# The ocean plays a crucial role in mitigating the effects of carbon dioxide (CO2) released into the atmosphere. It absorbs approximately 30% of the CO2 emissions resulting from human activities such as burning fossil fuels (e.g., car emissions) and changing land use (e.g., deforestation). However, as the levels of atmospheric CO2 increase, the amount of carbon dioxide absorbed by the ocean also increases. When CO2 dissolves in seawater, it leads to a series of chemical reactions that increase the concentration of hydrogen ions. This process has far-reaching implications for the ocean and the living organisms that inhabit it.
#
# <img src="images/Ocean%20Acidification%20Infographic_800x350.png" alt="description" width="900" height="auto"/>
#
# When carbon dioxide naturally dissolves into seawater, it forms carbonic acid (H2CO3) which dissociates into hydrogen ions (H+) and bicarbonate ions (HCO3-).
#
# ### Chemical Process Involved
#
# **CO<sub>2</sub> + H<sub>2</sub>O → H<sup>+</sup> + HCO<sub>3</sub><sup>-</sup>**
#
#
#
#
# ### Significance of the Equation
#
# The equation illustrates the chemical process by which carbon dioxide dissolves into seawater, contributing to ocean acidification. This phenomenon has profound implications for marine ecosystems, including disruptions to coral reefs, changes in marine species behavior, and impacts on shell-forming organisms. Understanding these chemical dynamics is critical for assessing and addressing the consequences of ocean acidification on global marine biodiversity and ecosystems.

# %% [markdown]
# ### Data Overview
# - The following analysis reads a CSV file containing carbonate chemistry data and displays the first few rows of the DataFrame.
#
# ### Histogram Analysis
# - A histogram is plotted for the bicarbonate ion (HCO3-) to visualize its distribution.
#
# ### Statistical Analysis with Student's t Distribution
# - Maximum Likelihood Estimates (MLE) are computed for the parameters of Student's t distribution for both H+ and HCO3- ions.
# - Histograms with Student's t fits are generated to compare the distribution of observed data with the fitted distribution.
#
# ### Relationship Analysis between H+ and HCO3-
# - A scatter plot with a regression line is plotted to explore the relationship between H+ and HCO3- ions.
#
# ### Polynomial Regression
# - Polynomial regression is applied to model the relationship between H+ and HCO3- ions.
# - Predictions are made for HCO3- levels given observed H+ concentrations.
#
# ### pH and H+ Relationship
# - A scatter plot is created to visualize the relationship between pH and H+ concentration.
# - Linear regression is performed to estimate H+ concentrations based on observed pH values.
#
# ### Percentage Change Analysis
# - Percentage changes in pH, H+ concentration, and HCO3- level are calculated between two observed data points.
# - Results are visualized using a bar chart to compare the percentage changes across different parameters.

# %% [markdown]
# ### Importing the necessary libraries for data manipulation and visualizations

# %%
import pandas as pd

# %% [markdown]
# ### Reading a CSV file to get the H+ ion and HCO3 values.

# %%
# Specify the file path
file_path = "data/co3.csv"

# Read the CSV file starting from row 300
df = pd.read_csv(file_path, skiprows=299)

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#                                         Event        Sample ID  \
# 0  TARA_20160531T1315Z_D_O-SRF_DOLPHIN-CARBOY  TARA_G100017007
# 1  TARA_20160531T1315Z_D_O-SRF_DOLPHIN-CARBOY  TARA_G100017008
# 2  TARA_20160531T1315Z_D_O-SRF_DOLPHIN-CARBOY  TARA_G100017009
# 3  TARA_20160607T1623Z_D_O-SRF_DOLPHIN-CARBOY  TARA_G100017138
# 4  TARA_20160607T1623Z_D_O-SRF_DOLPHIN-CARBOY  TARA_G100017139
#
#                  Sample label (Sampling-event label)  Depth top [m]  \
# 0  TARA_EVENT_20160531T1315Z_OA003-I00-S00_D_O-SR...            0.0
# 1  TARA_EVENT_20160531T1315Z_OA003-I00-S00_D_O-SR...            0.0
# 2  TARA_EVENT_20160531T1315Z_OA003-I00-S00_D_O-SR...            0.0
# 3  TARA_EVENT_20160607T1623Z_OA008-I00-S00_D_O-SR...            0.0
# 4  TARA_EVENT_20160607T1623Z_OA008-I00-S00_D_O-SR...            0.0
#
#    Depth bot [m]  Depth water [m] Sample label (Sampling-design label)  \
# 0            0.3             0.15                   OA003-I00-S00-C000
# ...

# %% [markdown]
# ### Quick overview of the DataFrame's structure and content

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 59 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Event                                            325 non-null    object
#  1   Sample ID                                        325 non-null    object
#  2   Sample label (Sampling-event label)              325 non-null    object
#  3   Depth top [m]                                    325 non-null    float64
#  4   Depth bot [m]                                    325 non-null    float64
#  5   Depth water [m]                                  325 non-null    float64
#  6   Sample label (Sampling-design label)             325 non-null    object
#  7   Sample comment (Sampling-design comment)         325 non-null    object
#  8   Env feature                                      325 non-null    object
# ...

# %%
df.isnull().sum(axis=0)
# Out:
# Event                                                0
# Sample ID                                            0
# Sample label (Sampling-event label)                  0
# Depth top [m]                                        0
# Depth bot [m]                                        0
# Depth water [m]                                      0
# Sample label (Sampling-design label)                 0
# Sample comment (Sampling-design comment)             0
# Env feature                                          0
# Sample label (Sampling-protocol label)               0
# Sample label (Sample-replicates label)               0
# Sample label (Technical-replicate label)             0
# Sample label (Analysis-label)                        0
# Comment (Analysis-comment)                           0
# QA (QA-flag bottle)                                  0
# QA (Stored with Hg2Cl2 (QA HgCl2 ...)                0
# QA (AT QA-flag)                                      0
# ...

# %%
df.describe()
# Out:
#        Depth top [m]  Depth bot [m]  Depth water [m]  \
# count     325.000000     325.000000       325.000000
# mean        2.969846       3.762769         3.366308
# std         4.126482       3.862889         3.969746
# min         0.000000       0.300000         0.150000
# 25%         0.000000       0.300000         0.150000
# 50%         1.000000       3.000000         2.000000
# 75%         5.000000       5.200000         5.100000
# max        20.000000      20.000000        20.000000
#
#        QA (Stored with Hg2Cl2 (QA HgCl2 ...)  AT [µmol/kg]  \
# count                             325.000000    325.000000
# mean                              257.538462   2286.606462
# std                               225.626910    110.072957
# min                               100.000000   1852.500000
# 25%                               200.000000   2241.300000
# 50%                               200.000000   2293.500000
# 75%                               200.000000   2342.600000
# ...

# %% [markdown]
# ### Plotting the Histogram for H+ values

# %%
# Plot histogram for H+
plt.figure(figsize=(10, 6))
plt.hist(df['H+'], bins=20, color='blue', alpha=0.7)
plt.xlabel('H+')
plt.ylabel('Frequency')
plt.title('Histogram of H+')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Plotting the Histogram for HCO3- Values

# %%
# Plot histogram for HCO3-
plt.figure(figsize=(10, 6))
plt.hist(df['HCO3-'], bins=20, color='green', alpha=0.7)
plt.xlabel('HCO3-')
plt.ylabel('Frequency')
plt.title('Histogram of HCO3-')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
from scipy.stats import t
import numpy as np

# Assuming 'data_Hplus' and 'data_HCO3minus' contain the observations from the 'H+' and 'HCO3-' columns
data_Hplus = df['H+']
data_HCO3minus = df['HCO3-']

# Remove non-finite values (NaNs and infinities)
data_Hplus = data_Hplus[np.isfinite(data_Hplus)]
data_HCO3minus = data_HCO3minus[np.isfinite(data_HCO3minus)]

# MLE estimation for Student's t distribution
nu_mle_Hplus, mu_mle_studentt_Hplus, sigma_mle_studentt_Hplus = t.fit(data_Hplus)
nu_mle_HCO3minus, mu_mle_studentt_HCO3minus, sigma_mle_studentt_HCO3minus = t.fit(data_HCO3minus)

print("\nMLE Estimates for Student's t Distribution (H+):")
print("Degrees of Freedom (ν):", nu_mle_Hplus)
print("Mean (μ):", mu_mle_studentt_Hplus)
print("Standard Deviation (σ):", sigma_mle_studentt_Hplus)

print("\nMLE Estimates for Student's t Distribution (HCO3-):")
print("Degrees of Freedom (ν):", nu_mle_HCO3minus)
print("Mean (μ):", mu_mle_studentt_HCO3minus)
print("Standard Deviation (σ):", sigma_mle_studentt_HCO3minus)
# Out:
# MLE Estimates for Student's t Distribution (H+):
# Degrees of Freedom (ν): 1.7477691937844695
# Mean (μ): 0.006978734899516044
# Standard Deviation (σ): 0.0003464786958805163
#
# MLE Estimates for Student's t Distribution (HCO3-):
# Degrees of Freedom (ν): 350613.1446351067
# Mean (μ): 1757.4623752360849
# Standard Deviation (σ): 109.94654940166569

# %%
# Histogram and Student's t fit for H+
plt.figure(figsize=(10,6))
plt.hist(data_Hplus, bins=20, density=True, alpha=0.6, color='blue', label='Histogram (H+)')
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = t.pdf(x, nu_mle_Hplus, mu_mle_studentt_Hplus, sigma_mle_studentt_Hplus)
plt.plot(x, p, 'k', linewidth=2, label="Student's t Fit")
plt.title("Histogram and Student's t Fit (H+)")
plt.grid(True)
plt.legend()

# %%
# Histogram and Student's t fit for HCO3-
plt.figure(figsize=(10, 6))
plt.hist(data_HCO3minus, bins=20, density=True, alpha=0.6, color='green', label='Histogram (HCO3-)')
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = t.pdf(x, nu_mle_HCO3minus, mu_mle_studentt_HCO3minus, sigma_mle_studentt_HCO3minus)
plt.plot(x, p, 'k', linewidth=2, label="Student's t Fit")
plt.title("Histogram and Student's t Fit (HCO3-)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Plotting the Scatter plot of HCO3 vs H+

# %%
import seaborn as sns

# Plotting a scatter plot with regression line
sns.regplot(x='HCO3-', y='H+', data=df)
plt.title('Scatter Plot of HCO3 vs H+ with Regression Line')
plt.xlabel('HCO3')
plt.ylabel('H+')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Utilize Linear Regression and Polynomial Features to extract insights

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Define the data
x = df['H+'].values
y = df['HCO3-'].values

# Remove NaN values if present
valid_indices = ~np.isnan(x) & ~np.isnan(y)
x = x[valid_indices]
y = y[valid_indices]

# Create polynomial features
poly_features = PolynomialFeatures(degree=2)  # You can adjust the degree as needed
X_poly = poly_features.fit_transform(x[:, np.newaxis])

# Fit polynomial regression model
model = LinearRegression()
model.fit(X_poly, y)

# Predict HCO3- levels for observed H+ values
observed_Hplus =  0.0091201083935591
X_observed = poly_features.transform(np.array([[observed_Hplus]]))
predicted_HCO3minus = model.predict(X_observed)

print("Predicted HCO3- level given observed H+ level of", observed_Hplus, ":", predicted_HCO3minus)

# Plot the relationship
plt.figure(figsize=(8, 6))
plt.scatter(x, y, color='blue', label='Observed Data')
plt.plot(x, model.predict(X_poly), color='red', label='Polynomial Regression')
plt.title('Relationship between H+ and HCO3-')
plt.xlabel('H+')
plt.ylabel('HCO3-')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Predicted HCO3- level given observed H+ level of 0.0091201083935591 : [1818.34334694]

# %% [markdown]
# ## Studying the relationship between pH and H+

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plotting a scatter plot with regression line for pH vs H+
sns.regplot(x='pH', y='H+', data=df)
plt.title('Scatter Plot of pH vs H+ with Regression Line')
plt.xlabel('pH')
plt.ylabel('H+')
plt.show()

# %% [markdown]
# ## Extracting insights between pH and H+ using Linear regression

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plotting H+ vs pH relationship
plt.figure(figsize=(8, 6))
sns.scatterplot(x='H+', y='pH', data=df)
plt.title('Relationship between H+ and pH')
plt.xlabel('H+ Concentration (µmol/kg)')
plt.ylabel('pH')
plt.grid(True)
plt.show()

# Fitting a linear regression model
x = df['pH'].values
y = df['H+'].values

# Remove NaN values if present
valid_indices = ~np.isnan(x) & ~np.isnan(y)
x = x[valid_indices]
y = y[valid_indices]

# Check if data is sufficient for linear regression
if len(x) < 2:
    print("Insufficient data for linear regression.")
else:
    slope, intercept, _, _, _ = linregress(x, y)

    # Example prediction given an observed pH value
    observed_pH = 8.04
    predicted_Hplus = 10**(-observed_pH) * 1e6  # Convert from mol/L to µmol/kg

    print("Predicted H+ concentration given observed pH value of", observed_pH, ":", predicted_Hplus, "µmol/kg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 26
#      24     print("Insufficient data for linear regression.")
#      25 else:
# ---> 26     slope, intercept, _, _, _ = linregress(x, y)
#      28     # Example prediction given an observed pH value
#      29     observed_pH = 8.04
#
# NameError: name 'linregress' is not defined

# %% [markdown]
# ## Predicted H+ and HCO3- based on observed pH of 8.04

# %%
observed_pH = 8.04
predicted_Hplus = 10**(-observed_pH) * 1e6  # Convert from mol/L to µmol/kg


observed_Hplus =  predicted_Hplus
X_observed = poly_features.transform(np.array([[observed_Hplus]]))
predicted_HCO3minus = model.predict(X_observed)
unit_HCO3minus = "µmol/kg"  


print("Predicted H+ concentration given observed pH value of", observed_pH, ":", predicted_Hplus, "µmol/kg")
print("Predicted HCO3- level given observed H+ level of", observed_Hplus, ":", predicted_HCO3minus[0], unit_HCO3minus)
# Out:
# Predicted H+ concentration given observed pH value of 8.04 : 0.009120108393559114 µmol/kg
# Predicted HCO3- level given observed H+ level of 0.009120108393559114 : 1818.3433469436795 µmol/kg

# %% [markdown]
# ## Predicted H+ and HCO3- based on observed pH of 8.12

# %%
observed_pH2 = 8.12
predicted_Hplus2 = 10**(-observed_pH2) * 1e6  # Convert from mol/L to µmol/kg


observed_Hplus2 =  predicted_Hplus2
X_observed2 = poly_features.transform(np.array([[observed_Hplus2]]))
predicted_HCO3minus2 = model.predict(X_observed2)

print("Predicted H+ concentration given observed pH value of", observed_pH2, ":", predicted_Hplus2, "µmol/kg")
print("Predicted HCO3- level given observed H+ level of", observed_Hplus2, ":", predicted_HCO3minus2[0], unit_HCO3minus)
# Out:
# Predicted H+ concentration given observed pH value of 8.12 : 0.007585775750291851 µmol/kg
# Predicted HCO3- level given observed H+ level of 0.007585775750291851 : 1766.6938433247456 µmol/kg

# %% [markdown]
# ## Calculating Percentage Differences

# %%
#8.04
pred_H_plus_1 = predicted_Hplus
pred_HCO3_minus_1 =  predicted_HCO3minus

#8.12
pred_H_plus_2 = predicted_Hplus2
pred_HCO3_minus_2 =  predicted_HCO3minus2


# Calculate percentage change for pH
percent_change_pH_reverse = ((8.04 - 8.12) / 8.12) * 100

# Calculate percentage change for H+ concentration
percent_change_Hplus_reverse = ((pred_H_plus_1 - pred_H_plus_2) / pred_H_plus_2) * 100

# Calculate percentage change for HCO3- level
percent_change_HCO3_reverse = ((pred_HCO3_minus_1 - pred_HCO3_minus_2) / pred_HCO3_minus_2) * 100

# Print results
print("Percentage change in pH from 8.12 to 8.04:", percent_change_pH_reverse, "%")
print("Percentage change in predicted H+ concentration from pH 8.12 to 8.04:", percent_change_Hplus_reverse, "%")
print("Percentage change in predicted HCO3- level from pH 8.12 to 8.04:", percent_change_HCO3_reverse, "%")
# Out:
# Percentage change in pH from 8.12 to 8.04: -0.9852216748768483 %
# Percentage change in predicted H+ concentration from pH 8.12 to 8.04: 20.226443461741304 %
# Percentage change in predicted HCO3- level from pH 8.12 to 8.04: [2.92351184] %

# %% [markdown]
# ## PLotting the Change in the pH, HCO3 and H+ concentration

# %%
import matplotlib.pyplot as plt

# Sample data from your output
percent_changes = {
    'pH': -0.9852216748768483,
    'H+ Concentration': 20.226443461741304,
    'HCO3- Level': 2.923511999
}

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(percent_changes.keys(), percent_changes.values(), color=['blue', 'green', 'red'])

# Adding labels and title
plt.xlabel('Parameter')
plt.ylabel('Percentage Change')
plt.title('Percentage Change in pH, H+ Concentration, and HCO3- Level')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

# Adding the percentage values on top of the bars
for i, (key, value) in enumerate(percent_changes.items()):
    plt.text(i, value, f'{value:.2f}%', ha='center', va='bottom')

# Show the plot
plt.tight_layout()  # Adjust layout for better fit
plt.show()

# %% [markdown]
# # Conclusion
#
# The analysis of ocean pH levels in the Pacific Ocean reveals a concerning trend towards acidification, with a decrease in pH and a notable increase in hydrogen ions (H+) concentration. Despite a moderate change in bicarbonate ions (HCO3-) concentration, indicating some buffering capacity, these shifts underscore the urgency of addressing ocean acidification.
#
#
# <img src="images/giphy.gif" alt="description" width="900" height="auto"/>
#
#
#
#
# As we move forward, we can use predictive modeling via ARIMA to forecast future ocean pH levels. This will provide us with valuable insights to create proactive strategies for minimizing the negative impact of ocean acidification. By taking a few critical precautions based on these models, we can potentially slow the rate of pH decline in the oceans:
#
# 1. **Transitioning to cleaner energy solutions:** Utilizing renewable energy sources can reduce our reliance on fossil fuels and subsequently lower CO2 emissio
# n2.
# 2. **Implementing advanced carbon capture and storage technologies:** Carbon capture technologies can be implemented significantjor emission points reduce the volume of CO2 released into the atmosphere significantly
# e3e.
# 3. **Promoting sustainable agricultural and forestry practices:** These practices can help increase carbon sequestration and reduce our overall carbon footp
# r4nt.
# 4. **Regulating industrial emissions:** Setting stricter emissions limits can encourage the adoption of cleaner technologies and practices in indus
# t5ies.
# 5. **Increasing public awareness and education:** Educating the public about the impacts of acidification and the importance of reducing carbon emissions can drive community-level change towards sustaina
# b
#
# In conclusion, these analyses demonstrate the interconnectedness of human activities, climate change, anthe ocean. We mustwe take concerted action to preserve marine ecosystems and ensure a sustainable future. With the help of predictive models and strategic interventions, we can mitigate the impact of acidification and safeguard marine life.
#
#
#
#
#
# <img src="images/e5b6a804efa541e8f6afa4be0c2ba9fe.gif" aldescriptione  width="900" height="auto"/>

# %% [markdown]
# # References

# %% [markdown]
# - **Effects of Ocean and Coastal Acidification on Marine Life**
#   - Website: [EPA - Effects of Ocean and Coastal Acidification on Marine Life](https://www.epa.gov/ocean-acidification/effects-ocean-and-coastal-acidification-marine-life)
#   - Information Source: Environmental Protection Agency (EPA)
#
# - **Understanding Ocean Acidification**
#   - Website: [NOAA Fisheries - Understanding Ocean Acidification](https://www.fisheries.noaa.gov/insight/understanding-ocean-acidification#:~:text=For%20good%20reason%2C%20ocean%20acidification,health%20is%20also%20a%20concern.)
#
# - **Ocean Acidification Indicator**
#   - Website: [OzCoasts - Ocean Acidification Indicator](https://ozcoasts.org.au/indicators/coastal-issues/ocean_acid/)
